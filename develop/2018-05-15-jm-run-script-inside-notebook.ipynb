# %%
# %run /mnt/jonathanmaher/equity-research-python-demo/src/single_stock_tear_sheet.py AAPL SPY 5
# Out:
# Entire data start date: 2013-05-20
# Entire data end date: 2018-05-14
# In-sample months: 53
# Out-of-sample months: 5
#                         All In-sample Out-of-sample
# Annual return         25.0%     25.9%         17.3%
# Cumulative returns   204.0%    181.1%          8.2%
# Annual volatility     23.0%     22.8%         24.9%
# Sharpe ratio           1.08      1.12          0.76
# Calmar ratio           0.78      0.81          1.28
# Stability              0.78      0.71          0.03
# Max drawdown         -32.1%    -32.1%        -13.4%
# Omega ratio            1.21      1.22          1.14
# Sortino ratio          1.62      1.67          1.16
# Skew                   0.04      0.01          0.25
# Kurtosis               3.69      4.07          1.12
# Tail ratio             1.01      1.02          0.90
# Daily value at risk   -2.8%     -2.8%         -3.1%
# Alpha                 -0.00      0.00          0.00
# Beta                   1.00      1.00          1.00
# ...

# %%
# %cd ..
# Out:
# /mnt/jonathanmaher

# %%
# %pwd
# Out:
# '/mnt/jonathanmaher/equity-research-python-demo'
